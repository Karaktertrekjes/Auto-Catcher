# %% [markdown]
# ### Clone the GitHub repository

# %%
# !git clone https://github.com/MehulKhanna/PokeGrinder.git
# %cd PokeGrinder
# Out:
# Cloning into 'PokeGrinder'...
# remote: Enumerating objects: 363, done.
# remote: Counting objects: 100% (149/149), done.
# remote: Compressing objects: 100% (88/88), done.
# remote: Total 363 (delta 101), reused 69 (delta 59), pack-reused 214 (from 1)
# Receiving objects: 100% (363/363), 5.52 MiB | 21.48 MiB/s, done.
# Resolving deltas: 100% (181/181), done.
# /content/PokeGrinder

# %% [markdown]
# ### Install discord.py-self

# %%
# %pip install git+https://github.com/dolfies/discord.py-self
# Out:
# Collecting git+https://github.com/dolfies/discord.py-self
#   Cloning https://github.com/dolfies/discord.py-self to /tmp/pip-req-build-hpl_i779
#   Running command git clone --filter=blob:none --quiet https://github.com/dolfies/discord.py-self /tmp/pip-req-build-hpl_i779
#   Resolved https://github.com/dolfies/discord.py-self to commit d0de36789f5832632476815b32661752a1a97748
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: aiohttp<4,>=3.7.4 in /usr/local/lib/python3.12/dist-packages (from discord.py-self==2.2.0a5295+gd0de3678) (3.13.4)
# Requirement already satisfied: curl_cffi<1,>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from discord.py-self==2.2.0a5295+gd0de3678) (0.14.0)
# Requirement already satisfied: tzlocal<6,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from discord.py-self==2.2.0a5295+gd0de3678) (5.3.1)
# Collecting discord_protos<2.0.0 (from discord.py-self==2.2.0a5295+gd0de3678)
#   Downloading discord_protos-1.2.156-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.7.4->discord.py-self==2.2.0a5295+gd0de3678) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.7.4->discord.py-self==2.2.0a5295+gd0de3678) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.7.4->discord.py-self==2.2.0a5295+gd0de3678) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.7.4->discord.py-self==2.2.0a5295+gd0de3678) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.7.4->discord.py-self==2.2.0a5295+gd0de3678) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.7.4->discord.py-self==2.2.0a5295+gd0de3678) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.7.4->discord.py-self==2.2.0a5295+gd0de3678) (1.23.0)
# Requirement already satisfied: cffi>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from curl_cffi<1,>=0.14.0->discord.py-self==2.2.0a5295+gd0de3678) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in /usr/local/lib/python3.12/dist-packages (from curl_cffi<1,>=0.14.0->discord.py-self==2.2.0a5295+gd0de3678) (2026.2.25)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from discord_protos<2.0.0->discord.py-self==2.2.0a5295+gd0de3678) (5.29.6)
# Collecting mypy-protobuf<6 (from discord_protos<2.0.0->discord.py-self==2.2.0a5295+gd0de3678)
#   Downloading mypy_protobuf-5.0.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.12/dist-packages (from aiosignal>=1.4.0->aiohttp<4,>=3.7.4->discord.py-self==2.2.0a5295+gd0de3678) (4.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12.0->curl_cffi<1,>=0.14.0->discord.py-self==2.2.0a5295+gd0de3678) (3.0)
# Collecting types-protobuf>=4.24 (from mypy-protobuf<6->discord_protos<2.0.0->discord.py-self==2.2.0a5295+gd0de3678)
#   Downloading types_protobuf-7.34.1.20260408-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.17.0->aiohttp<4,>=3.7.4->discord.py-self==2.2.0a5295+gd0de3678) (3.11)
# Downloading discord_protos-1.2.156-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.1/183.1 kB 5.9 MB/s eta 0:00:00
# Downloading mypy_protobuf-5.0.0-py3-none-any.whl (26 kB)
# Downloading types_protobuf-7.34.1.20260408-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 6.8 MB/s eta 0:00:00
# Building wheels for collected packages: discord.py-self
#   Building wheel for discord.py-self (pyproject.toml) ... done
#   Created wheel for discord.py-self: filename=discord_py_self-2.2.0a5295+gd0de3678-py3-none-any.whl size=1293298 sha256=10307ef5268094637b4edacf072d00e140022c99dd2b066a926c7e713513fb34
#   Stored in directory: /tmp/pip-ephem-wheel-cache-rpj0ep2t/wheels/3d/5d/1a/542641422b9e5aa9f4855d4e5116c2c691052ad964eaed3876
# Successfully built discord.py-self
# Installing collected packages: types-protobuf, mypy-protobuf, discord_protos, discord.py-self
# Successfully installed discord.py-self-2.2.0a5295+gd0de3678 discord_protos-1.2.156 mypy-protobuf-5.0.0 types-protobuf-7.34.1.20260408

# %% [markdown]
# ### Install requirements

# %%
# !python -m pip install -r requirements.txt
# Out:
# Collecting git+https://github.com/dolfies/discord.py-self (from -r requirements.txt (line 4))
#   Cloning https://github.com/dolfies/discord.py-self to /tmp/pip-req-build-jnqsbpac
#   Running command git clone --filter=blob:none --quiet https://github.com/dolfies/discord.py-self /tmp/pip-req-build-jnqsbpac
#   Resolved https://github.com/dolfies/discord.py-self to commit d0de36789f5832632476815b32661752a1a97748
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (13.9.4)
# Collecting ultralytics (from -r requirements.txt (line 2))
#   Downloading ultralytics-8.4.36-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (11.3.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->-r requirements.txt (line 1)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->-r requirements.txt (line 1)) (2.20.0)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics->-r requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics->-r requirements.txt (line 2)) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics->-r requirements.txt (line 2)) (4.13.0.92)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics->-r requirements.txt (line 2)) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics->-r requirements.txt (line 2)) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics->-r requirements.txt (line 2)) (1.16.3)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics->-r requirements.txt (line 2)) (2.10.0+cpu)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics->-r requirements.txt (line 2)) (0.25.0+cpu)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics->-r requirements.txt (line 2)) (5.9.5)
# Requirement already satisfied: polars>=0.20.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics->-r requirements.txt (line 2)) (1.35.2)
# Collecting ultralytics-thop>=2.0.18 (from ultralytics->-r requirements.txt (line 2))
#   Downloading ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: aiohttp<4,>=3.7.4 in /usr/local/lib/python3.12/dist-packages (from discord.py-self==2.2.0a5295+gd0de3678->-r requirements.txt (line 4)) (3.13.4)
# Requirement already satisfied: curl_cffi<1,>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from discord.py-self==2.2.0a5295+gd0de3678->-r requirements.txt (line 4)) (0.14.0)
# Requirement already satisfied: tzlocal<6,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from discord.py-self==2.2.0a5295+gd0de3678->-r requirements.txt (line 4)) (5.3.1)
# Requirement already satisfied: discord_protos<2.0.0 in /usr/local/lib/python3.12/dist-packages (from discord.py-self==2.2.0a5295+gd0de3678->-r requirements.txt (line 4)) (1.2.156)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.7.4->discord.py-self==2.2.0a5295+gd0de3678->-r requirements.txt (line 4)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.7.4->discord.py-self==2.2.0a5295+gd0de3678->-r requirements.txt (line 4)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.7.4->discord.py-self==2.2.0a5295+gd0de3678->-r requirements.txt (line 4)) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.7.4->discord.py-self==2.2.0a5295+gd0de3678->-r requirements.txt (line 4)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.7.4->discord.py-self==2.2.0a5295+gd0de3678->-r requirements.txt (line 4)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.7.4->discord.py-self==2.2.0a5295+gd0de3678->-r requirements.txt (line 4)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.7.4->discord.py-self==2.2.0a5295+gd0de3678->-r requirements.txt (line 4)) (1.23.0)
# Requirement already satisfied: cffi>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from curl_cffi<1,>=0.14.0->discord.py-self==2.2.0a5295+gd0de3678->-r requirements.txt (line 4)) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in /usr/local/lib/python3.12/dist-packages (from curl_cffi<1,>=0.14.0->discord.py-self==2.2.0a5295+gd0de3678->-r requirements.txt (line 4)) (2026.2.25)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from discord_protos<2.0.0->discord.py-self==2.2.0a5295+gd0de3678->-r requirements.txt (line 4)) (5.29.6)
# Requirement already satisfied: mypy-protobuf<6 in /usr/local/lib/python3.12/dist-packages (from discord_protos<2.0.0->discord.py-self==2.2.0a5295+gd0de3678->-r requirements.txt (line 4)) (5.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->-r requirements.txt (line 1)) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics->-r requirements.txt (line 2)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics->-r requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics->-r requirements.txt (line 2)) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics->-r requirements.txt (line 2)) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics->-r requirements.txt (line 2)) (26.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics->-r requirements.txt (line 2)) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics->-r requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.35.2 in /usr/local/lib/python3.12/dist-packages (from polars>=0.20.0->ultralytics->-r requirements.txt (line 2)) (1.35.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics->-r requirements.txt (line 2)) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics->-r requirements.txt (line 2)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics->-r requirements.txt (line 2)) (2.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics->-r requirements.txt (line 2)) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics->-r requirements.txt (line 2)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics->-r requirements.txt (line 2)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics->-r requirements.txt (line 2)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics->-r requirements.txt (line 2)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics->-r requirements.txt (line 2)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics->-r requirements.txt (line 2)) (2025.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12.0->curl_cffi<1,>=0.14.0->discord.py-self==2.2.0a5295+gd0de3678->-r requirements.txt (line 4)) (3.0)
# Requirement already satisfied: types-protobuf>=4.24 in /usr/local/lib/python3.12/dist-packages (from mypy-protobuf<6->discord_protos<2.0.0->discord.py-self==2.2.0a5295+gd0de3678->-r requirements.txt (line 4)) (7.34.1.20260408)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics->-r requirements.txt (line 2)) (3.0.3)
# Downloading ultralytics-8.4.36-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 20.7 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.4.36 ultralytics-thop-2.0.18

# %% [markdown]
# # Now edit your config
# Please increase HuntingCooldown, FishingCooldown and RetryCooldown by a few hundred milliseconds to avoid "Please wait" messages.
#
# For example,
# Change "HuntingCooldown": 8.4 to "HuntingCooldown": 8.9

# %% [markdown]
# # Run PokeGrinder

# %%
# !python main.py p
# Out:
# 2026-04-08 17:45:58 INFO     discord.client Logging in using static token.
# 2026-04-08 17:45:58 INFO     discord.http Found user agent "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/147.0.0.0 Safari/537.36", build number 524923.
# 2026-04-08 17:45:58 INFO     discord.http Found TLS fingerprint target "chrome142".
# 2026-04-08 17:45:59 INFO     discord.gateway Connected to Gateway (session ID: 2a29a6a559d0ee921acd3d1fd327753e).
# 17:45:59  [SYSTEM]  Ready to Find n Grind!
# 17:46:02  [UNCOMMON]  Unown
# 17:46:16  [UNCOMMON]  Nidorino
# 17:46:28  [UNCOMMON]  Dunsparce
